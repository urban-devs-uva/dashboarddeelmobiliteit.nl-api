# %%
# Imports

import pandas as pd

# %%
# Read and clean the data we will merge

flux_df = pd.read_pickle("data/flux_df.pkl")
min_max_df = pd.read_pickle("data/min_max_df.pkl")
avg_df = pd.read_pickle("data/avg_df.pkl")

# flux_df has generic column names, let's fix that
flux_df = flux_df.rename(
    columns=lambda column: column + "_flux" if column != "day" else column
)

# This gives each observation a unique key which makes merging the dataframes easier
def get_id_column(df):
    return flux_df.index + "_" + flux_df["day"].astype(str)


flux_df["id"] = get_id_column(flux_df)
min_max_df["id"] = get_id_column(min_max_df)
avg_df["id"] = get_id_column(avg_df)

# %%
# Merge the data
df_merged = pd.merge(flux_df, min_max_df, on=["id", "day"])
df_merged = df_merged.merge(avg_df, on=["id", "day"])

# let's set df_merged's index to also be the neighbourhood of the observation
# this will help with handling the data later
df_merged.index = flux_df.index

# our "day" variable is an independent variable, let's move it back to the left
column_to_move = df_merged.pop("day")
df_merged.insert(0, "day", column_to_move)

# %%
# let's add the day of the week as data by using our "day" variable
def get_week_day(day):
    day = day % 7
    # 01/10/23 was a Sunday, therefore day 0 is Sunday, day 1 Monday and so forth.
    return (
        "sunday"
        if day == 0
        else "monday"
        if day == 1
        else "tuesday"
        if day == 2
        else "wednesday"
        if day == 3
        else "thursday"
        if day == 4
        else "friday"
        if day == 5
        else "saturday"
    )

# using .insert to have the column on the left
df_merged.insert(0, "week_day", df_merged["day"].apply(get_week_day))

# %%
# Now let's merge our google maps data
df_gmaps = pd.read_pickle("data/clean_gmaps.pkl")

def merge_gmaps_data():
    # Since in both our merged df and the gmaps df, the neighbourhoods are indexed in
    # alphabetical order, just doing this matches them perfectly
    for column in df_gmaps.columns:
        df_merged[column] = df_gmaps[column]

# This adds a lot of data that we can use, not all of which is necessarily useful
merge_gmaps_data()

display(df_merged)
# Out:
#                                  week_day  day  bicycle_flux  \
# Aetsveld/Oostelijke Vechtoever     sunday    0           0.0
# Amstel III/Bullewijk               sunday    0           0.0
# Amsterdamse Poort e.o.             sunday    0           0.0
# Apollobuurt                        sunday    0           7.0
# Banne Buiksloot                    sunday    0           0.0
# ...                                   ...  ...           ...
# Westlandgracht                  wednesday   31           5.0
# Willemspark                     wednesday   31           0.0
# Zeeburgereiland/Bovendiep       wednesday   31           0.0
# Zuid Pijp                       wednesday   31           0.0
# Zuidas                          wednesday   31           1.0
#
#                                 cargo_bicycle_flux  moped_flux  scooter_flux  \
# Aetsveld/Oostelijke Vechtoever                 0.0         0.0           0.0
# Amstel III/Bullewijk                           0.0        36.0           0.0
# Amsterdamse Poort e.o.                         1.0        17.0           0.0
# Apollobuurt                                    0.0        46.0           0.0
# Banne Buiksloot                                0.0         0.0           0.0
# ...                                            ...         ...           ...
# Westlandgracht                                 0.0         1.0           0.0
# Willemspark                                    0.0         0.0           0.0
# Zeeburgereiland/Bovendiep                      0.0         0.0           0.0
# Zuid Pijp                                      0.0         1.0           0.0
# Zuidas                                         0.0         0.0           0.0
#
#                                                               id  bicycle_min  \
# Aetsveld/Oostelijke Vechtoever  Aetsveld/Oostelijke Vechtoever_0          0.0
# Amstel III/Bullewijk                      Amstel III/Bullewijk_0          0.0
# Amsterdamse Poort e.o.                  Amsterdamse Poort e.o._0          0.0
# Apollobuurt                                        Apollobuurt_0          2.0
# Banne Buiksloot                                Banne Buiksloot_0          0.0
# ...                                                          ...          ...
# Westlandgracht                                 Westlandgracht_31         14.0
# Willemspark                                       Willemspark_31          0.0
# Zeeburgereiland/Bovendiep           Zeeburgereiland/Bovendiep_31          1.0
# Zuid Pijp                                           Zuid Pijp_31          2.0
# Zuidas                                                 Zuidas_31         48.0
#
#                                 bicycle_max  bicycle_diff  ...  \
# Aetsveld/Oostelijke Vechtoever          0.0           0.0  ...
# Amstel III/Bullewijk                    0.0           0.0  ...
# Amsterdamse Poort e.o.                  0.0           0.0  ...
# Apollobuurt                             5.0           3.0  ...
# Banne Buiksloot                         0.0           0.0  ...
# ...                                     ...           ...  ...
# Westlandgracht                         19.0           5.0  ...
# Willemspark                             0.0           0.0  ...
# Zeeburgereiland/Bovendiep               1.0           0.0  ...
# Zuid Pijp                               2.0           0.0  ...
# Zuidas                                 49.0           1.0  ...
#
#                                 nearest_metro_station_name_bicycling  \
# Aetsveld/Oostelijke Vechtoever                           Gaasperplas
# Amstel III/Bullewijk                             Station Holendrecht
# Amsterdamse Poort e.o.                         Station Bijlmer ArenA
# Apollobuurt                                             Station Zuid
# Banne Buiksloot                                          Noorderpark
# ...                                                              ...
# Westlandgracht                                     Henk Sneevlietweg
# Willemspark                                          Amstelveenseweg
# Zeeburgereiland/Bovendiep                          Verrijn Stuartweg
# Zuid Pijp                                                    De Pijp
# Zuidas                                                  Station Zuid
#
#                                 nearest_metro_station_distance_bicycling  \
# Aetsveld/Oostelijke Vechtoever                                      8031
# Amstel III/Bullewijk                                                 560
# Amsterdamse Poort e.o.                                               411
# Apollobuurt                                                         1343
# Banne Buiksloot                                                     1633
# ...                                                                  ...
# Westlandgracht                                                       628
# Willemspark                                                         1977
# Zeeburgereiland/Bovendiep                                           5595
# Zuid Pijp                                                              0
# Zuidas                                                               112
#
#                                 nearest_train_station_name_driving  \
# Aetsveld/Oostelijke Vechtoever     Amsterdam Bijlmer ArenA Station
# Amstel III/Bullewijk                 Amsterdam Holendrecht Station
# Amsterdamse Poort e.o.             Amsterdam Bijlmer ArenA Station
# Apollobuurt                                 Amsterdam Zuid Station
# Banne Buiksloot                       Amsterdam Sloterdijk Station
# ...                                                            ...
# Westlandgracht                          Amsterdam Lelylaan Station
# Willemspark                             Amsterdam Lelylaan Station
# Zeeburgereiland/Bovendiep            Amsterdam Muiderpoort Station
# Zuid Pijp                                    Amsterdam RAI Station
# Zuidas                                      Amsterdam Zuid Station
#
#                                 nearest_train_station_distance_driving  \
# Aetsveld/Oostelijke Vechtoever                                   11934
# Amstel III/Bullewijk                                               695
# Amsterdamse Poort e.o.                                             671
# Apollobuurt                                                       1634
# Banne Buiksloot                                                  10657
# ...                                                                ...
# Westlandgracht                                                    1392
# Willemspark                                                       2909
# Zeeburgereiland/Bovendiep                                         3977
# Zuid Pijp                                                         2404
# Zuidas                                                               4
#
#                                 nearest_metro_station_name_driving  \
# Aetsveld/Oostelijke Vechtoever                         Gaasperplas
# Amstel III/Bullewijk                           Station Holendrecht
# Amsterdamse Poort e.o.                       Station Bijlmer ArenA
# Apollobuurt                                                De Pijp
# Banne Buiksloot                                        Noorderpark
# ...                                                            ...
# Westlandgracht                                   Henk Sneevlietweg
# Willemspark                                        Heemstedestraat
# Zeeburgereiland/Bovendiep                             Weesperplein
# Zuid Pijp                                                  De Pijp
# Zuidas                                                 Station RAI
#
#                                 nearest_metro_station_distance_driving  \
# Aetsveld/Oostelijke Vechtoever                                    7997
# Amstel III/Bullewijk                                               941
# Amsterdamse Poort e.o.                                             671
# Apollobuurt                                                       2145
# Banne Buiksloot                                                   1881
# ...                                                                ...
# Westlandgracht                                                     812
# Willemspark                                                       2345
# Zeeburgereiland/Bovendiep                                         5785
# Zuid Pijp                                                            0
# Zuidas                                                            2043
#
#                                 nearest_train_station_name_transit  \
# Aetsveld/Oostelijke Vechtoever     Amsterdam Bijlmer ArenA Station
# Amstel III/Bullewijk                 Amsterdam Holendrecht Station
# Amsterdamse Poort e.o.             Amsterdam Bijlmer ArenA Station
# Apollobuurt                                 Amsterdam Zuid Station
# Banne Buiksloot                         Amsterdam Centraal Station
# ...                                                            ...
# Westlandgracht                          Amsterdam Lelylaan Station
# Willemspark                             Amsterdam Lelylaan Station
# Zeeburgereiland/Bovendiep            Amsterdam Muiderpoort Station
# Zuid Pijp                            Amsterdam Muiderpoort Station
# Zuidas                                      Amsterdam Zuid Station
#
#                                 nearest_train_station_distance_transit  \
# Aetsveld/Oostelijke Vechtoever                                   13299
# Amstel III/Bullewijk                                               719
# Amsterdamse Poort e.o.                                             378
# Apollobuurt                                                       1902
# Banne Buiksloot                                                   4919
# ...                                                                ...
# Westlandgracht                                                    1979
# Willemspark                                                       2479
# Zeeburgereiland/Bovendiep                                         2685
# Zuid Pijp                                                         2610
# Zuidas                                                              49
#
#                                 nearest_metro_station_name_transit  \
# Aetsveld/Oostelijke Vechtoever                         Gaasperplas
# Amstel III/Bullewijk                           Station Holendrecht
# Amsterdamse Poort e.o.                       Station Bijlmer ArenA
# Apollobuurt                                           Station Zuid
# Banne Buiksloot                                        Noorderpark
# ...                                                            ...
# Westlandgracht                                   Henk Sneevlietweg
# Willemspark                                        Amstelveenseweg
# Zeeburgereiland/Bovendiep                             Wibautstraat
# Zuid Pijp                                             Wibautstraat
# Zuidas                                                Station Zuid
#
#                                 nearest_metro_station_distance_transit
# Aetsveld/Oostelijke Vechtoever                                  8753.0
# Amstel III/Bullewijk                                             560.0
# Amsterdamse Poort e.o.                                           378.0
# Apollobuurt                                                     1253.0
# Banne Buiksloot                                                 1436.0
# ...                                                                ...
# Westlandgracht                                                   619.0
# Willemspark                                                     2084.0
# Zeeburgereiland/Bovendiep                                       4889.0
# Zuid Pijp                                                       1275.0
# Zuidas                                                           112.0
#
# [3520 rows x 39 columns]

# %%
# Below code merges population data
ams_data = pd.read_csv("data/amsterdam_data.csv")

# Prepare ams_data for merging
ams_data.set_index('Name', inplace=True)
ams_data = ams_data.rename_axis(None)
ams_data = ams_data.drop('Unnamed: 0', axis=1, errors='ignore')

# Loop through the index of df_merged
for index in df_merged.index:
    # Check if the index is present in ams_data
    if index in ams_data.index:
        # Get the corresponding row in ams_data using the index
        ams_row = ams_data.loc[index]
        
        # Extract the population number from the 'Population' column
        population_number = ams_row['Population']
        
        # Update the 'Population' column in df_merged
        df_merged.at[index, 'population'] = population_number

        # Loop through age group columns in ams_data
        age_columns = ['0 - 3 years (%)', '4 - 12 years (%)', '13 - 17 years (%)', '18 - 26 years (%)', '27 - 65 years (%)', '66 + years (%)']
        highest_percentage_age_column = max(age_columns, key=lambda col: ams_row[col])

        # Update the 'highest_percentage_age' column in df_merged
        df_merged.at[index, 'highest_percentage_age'] = highest_percentage_age_column

        # Extract income data
        income_number = ams_row['Predicted mean disposable household income']

        # Add to income column
        df_merged.at[index, 'predicted_mean_disposable_household_income'] = income_number
        

# Save df_merged into a pickle file
df_merged.to_pickle("regression_data.pkl")

display(df_merged)
# Out:
#                                  week_day  day  bicycle_flux  \
# Aetsveld/Oostelijke Vechtoever     sunday    0           0.0
# Amstel III/Bullewijk               sunday    0           0.0
# Amsterdamse Poort e.o.             sunday    0           0.0
# Apollobuurt                        sunday    0           7.0
# Banne Buiksloot                    sunday    0           0.0
# ...                                   ...  ...           ...
# Westlandgracht                  wednesday   31           5.0
# Willemspark                     wednesday   31           0.0
# Zeeburgereiland/Bovendiep       wednesday   31           0.0
# Zuid Pijp                       wednesday   31           0.0
# Zuidas                          wednesday   31           1.0
#
#                                 cargo_bicycle_flux  moped_flux  scooter_flux  \
# Aetsveld/Oostelijke Vechtoever                 0.0         0.0           0.0
# Amstel III/Bullewijk                           0.0        36.0           0.0
# Amsterdamse Poort e.o.                         1.0        17.0           0.0
# Apollobuurt                                    0.0        46.0           0.0
# Banne Buiksloot                                0.0         0.0           0.0
# ...                                            ...         ...           ...
# Westlandgracht                                 0.0         1.0           0.0
# Willemspark                                    0.0         0.0           0.0
# Zeeburgereiland/Bovendiep                      0.0         0.0           0.0
# Zuid Pijp                                      0.0         1.0           0.0
# Zuidas                                         0.0         0.0           0.0
#
#                                                               id  bicycle_min  \
# Aetsveld/Oostelijke Vechtoever  Aetsveld/Oostelijke Vechtoever_0          0.0
# Amstel III/Bullewijk                      Amstel III/Bullewijk_0          0.0
# Amsterdamse Poort e.o.                  Amsterdamse Poort e.o._0          0.0
# Apollobuurt                                        Apollobuurt_0          2.0
# Banne Buiksloot                                Banne Buiksloot_0          0.0
# ...                                                          ...          ...
# Westlandgracht                                 Westlandgracht_31         14.0
# Willemspark                                       Willemspark_31          0.0
# Zeeburgereiland/Bovendiep           Zeeburgereiland/Bovendiep_31          1.0
# Zuid Pijp                                           Zuid Pijp_31          2.0
# Zuidas                                                 Zuidas_31         48.0
#
#                                 bicycle_max  bicycle_diff  ...  \
# Aetsveld/Oostelijke Vechtoever          0.0           0.0  ...
# Amstel III/Bullewijk                    0.0           0.0  ...
# Amsterdamse Poort e.o.                  0.0           0.0  ...
# Apollobuurt                             5.0           3.0  ...
# Banne Buiksloot                         0.0           0.0  ...
# ...                                     ...           ...  ...
# Westlandgracht                         19.0           5.0  ...
# Willemspark                             0.0           0.0  ...
# Zeeburgereiland/Bovendiep               1.0           0.0  ...
# Zuid Pijp                               2.0           0.0  ...
# Zuidas                                 49.0           1.0  ...
#
#                                 nearest_train_station_distance_driving  \
# Aetsveld/Oostelijke Vechtoever                                   11934
# Amstel III/Bullewijk                                               695
# Amsterdamse Poort e.o.                                             671
# Apollobuurt                                                       1634
# Banne Buiksloot                                                  10657
# ...                                                                ...
# Westlandgracht                                                    1392
# Willemspark                                                       2909
# Zeeburgereiland/Bovendiep                                         3977
# Zuid Pijp                                                         2404
# Zuidas                                                               4
#
#                                 nearest_metro_station_name_driving  \
# Aetsveld/Oostelijke Vechtoever                         Gaasperplas
# Amstel III/Bullewijk                           Station Holendrecht
# Amsterdamse Poort e.o.                       Station Bijlmer ArenA
# Apollobuurt                                                De Pijp
# Banne Buiksloot                                        Noorderpark
# ...                                                            ...
# Westlandgracht                                   Henk Sneevlietweg
# Willemspark                                        Heemstedestraat
# Zeeburgereiland/Bovendiep                             Weesperplein
# Zuid Pijp                                                  De Pijp
# Zuidas                                                 Station RAI
#
#                                 nearest_metro_station_distance_driving  \
# Aetsveld/Oostelijke Vechtoever                                    7997
# Amstel III/Bullewijk                                               941
# Amsterdamse Poort e.o.                                             671
# Apollobuurt                                                       2145
# Banne Buiksloot                                                   1881
# ...                                                                ...
# Westlandgracht                                                     812
# Willemspark                                                       2345
# Zeeburgereiland/Bovendiep                                         5785
# Zuid Pijp                                                            0
# Zuidas                                                            2043
#
#                                 nearest_train_station_name_transit  \
# Aetsveld/Oostelijke Vechtoever     Amsterdam Bijlmer ArenA Station
# Amstel III/Bullewijk                 Amsterdam Holendrecht Station
# Amsterdamse Poort e.o.             Amsterdam Bijlmer ArenA Station
# Apollobuurt                                 Amsterdam Zuid Station
# Banne Buiksloot                         Amsterdam Centraal Station
# ...                                                            ...
# Westlandgracht                          Amsterdam Lelylaan Station
# Willemspark                             Amsterdam Lelylaan Station
# Zeeburgereiland/Bovendiep            Amsterdam Muiderpoort Station
# Zuid Pijp                            Amsterdam Muiderpoort Station
# Zuidas                                      Amsterdam Zuid Station
#
#                                 nearest_train_station_distance_transit  \
# Aetsveld/Oostelijke Vechtoever                                   13299
# Amstel III/Bullewijk                                               719
# Amsterdamse Poort e.o.                                             378
# Apollobuurt                                                       1902
# Banne Buiksloot                                                   4919
# ...                                                                ...
# Westlandgracht                                                    1979
# Willemspark                                                       2479
# Zeeburgereiland/Bovendiep                                         2685
# Zuid Pijp                                                         2610
# Zuidas                                                              49
#
#                                 nearest_metro_station_name_transit  \
# Aetsveld/Oostelijke Vechtoever                         Gaasperplas
# Amstel III/Bullewijk                           Station Holendrecht
# Amsterdamse Poort e.o.                       Station Bijlmer ArenA
# Apollobuurt                                           Station Zuid
# Banne Buiksloot                                        Noorderpark
# ...                                                            ...
# Westlandgracht                                   Henk Sneevlietweg
# Willemspark                                        Amstelveenseweg
# Zeeburgereiland/Bovendiep                             Wibautstraat
# Zuid Pijp                                             Wibautstraat
# Zuidas                                                Station Zuid
#
#                                 nearest_metro_station_distance_transit  \
# Aetsveld/Oostelijke Vechtoever                                  8753.0
# Amstel III/Bullewijk                                             560.0
# Amsterdamse Poort e.o.                                           378.0
# Apollobuurt                                                     1253.0
# Banne Buiksloot                                                 1436.0
# ...                                                                ...
# Westlandgracht                                                   619.0
# Willemspark                                                     2084.0
# Zeeburgereiland/Bovendiep                                       4889.0
# Zuid Pijp                                                       1275.0
# Zuidas                                                           112.0
#
#                                 population  highest_percentage_age  \
# Aetsveld/Oostelijke Vechtoever      4402.0       27 - 65 years (%)
# Amstel III/Bullewijk                3546.0       18 - 26 years (%)
# Amsterdamse Poort e.o.              8272.0       27 - 65 years (%)
# Apollobuurt                         8825.0       27 - 65 years (%)
# Banne Buiksloot                    14806.0       27 - 65 years (%)
# ...                                    ...                     ...
# Westlandgracht                     13194.0       27 - 65 years (%)
# Willemspark                         5561.0       27 - 65 years (%)
# Zeeburgereiland/Bovendiep           5679.0       27 - 65 years (%)
# Zuid Pijp                           7917.0       27 - 65 years (%)
# Zuidas                              5218.0       27 - 65 years (%)
#
#                                 predicted_mean_disposable_household_income
# Aetsveld/Oostelijke Vechtoever                                     39520.1
# Amstel III/Bullewijk                                               39520.1
# Amsterdamse Poort e.o.                                             39520.1
# Apollobuurt                                                        88559.5
# Banne Buiksloot                                                    42139.0
# ...                                                                    ...
# Westlandgracht                                                     46335.9
# Willemspark                                                        89532.3
# Zeeburgereiland/Bovendiep                                          42204.7
# Zuid Pijp                                                          39976.9
# Zuidas                                                             71679.0
#
# [3520 rows x 42 columns]
